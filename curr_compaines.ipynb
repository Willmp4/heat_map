# %%
# from geopy.geocoders import Nominatim
# import pandas as pd

# companies = ["Attestor Capital", "Global Prime Partners", "Anaplan", "Invesco", "Zeus Capital", "Barratt Homes", "Adyen",
#              "Engine MHP", "Bainbridge Partners LLP", "Health Care - NHS", "Essence Global", "MFS UK", "NAO", "RTL AdConect",
#              "iwoca", "Cromwell", "EVERCORE", "H&M", "GAP", "Polen Capital", "Which Group", "Prime Energy", "Ninetyone PLC",
#              "TPG", "CBC group", "Blackstone", "Titan assest management", "Wizer", "Partners group UK", "7 Bridges LDP",
#                 "Fifth Fifth Season", "Time Family", "Weight watchers", "Alpha", "Remidy", "Ralph Lauren", "Baxter",
#                 "Impact Assets", "Pharmacierge", "Ahli United Bank", "Attestor Limited", "Albemarle Independent College",
#                 "Berkeley Energy Services", "BMW", "BMG Rights Management", "Broadgate Estates", "Brecher LLP",
#                 "British Land Company", "Cape Ann Asset Management", "EBRD", "Coller Capital", "Forsters Service Company",
#                 "Global Blue UK", "Global Holdings", "Hyde Park Residence", "Helix Property Advisor", "Helios Towers Africa",
#                 "Independent Franchise Partners", "Ninety Percent of Everything", "Odey Asset Mgmt", "Premier League",
#                 "Quantum Pacific", "Rede Partners", "WPP 2005 Ltd", "Hamilton Court FX", "Stanhope Capital LLP", "TPG Europe",
#                 "Crossroads Estates", "Underwood &Co", "Renisance Capital", "EMK Capital", "We Match Live", "Lendhub",
#              "Perbak Capital Partners", "Bain Capital Private Equity (Europe) LLP", "Barclays",
#              "BlackRock Investment Management (UK) Ltd", "BNP Paribas", "Centrica", "Christian Dior UK", "Cluttons LLP",
#              "Cushman & Wakefield SSO", "HCA", "KPMG LLP", "London Stock Exchange", "Mercer", "Multiplex Construction Europe Ltd",
#              "Oath (UK) Limited", "Pricewaterhouse Coopers", "Samsung Electronics (UK) Ltd", "Societe Generale",
#              "Talk Talk Plc", "The Boston Consulting Group UK LLP", "Travers Smith LLP", "Aviva - Large Corporates - HCGLRG",
#              "Simplyhealth Partner Portal", "Accenture", "MediCash", "Farfetch", "Bank of America", "PricewaterhouseCoopers Services Ltd",
#              "Perkbox Limited", "Immediate Media", "The Crown Estate", "Ares Management Limited", "Wagamama", "Tastecard",
#              "Tiger Recruitment Ltd", "Avanade (UK) Limited", "JP Morgan", "COGS Employee Benefits - Cogs Salary Plus",
#              "Lane Clark & Peacock LLP", "PricewaterhouseCoopers Services Ltd"]


companies = ["Fifth Fifth Season, 48 Tottenham Court Rd, Bloomsbury, London W1T 2EG, United Kingdom",
             "Time Family, 20-22 Wenlock Rd, Hoxton, London N1 7GU, United Kingdom",
             "Weight Watchers, 37-39 Oxford St, Soho, London W1D 2DU, United Kingdom",
             "Alpha, 20 Old Bailey, London EC4M 7AN, United Kingdom",            
             "Remedy Analytics, 5 New St Square, London EC4A 3TW, United Kingdom",           
             "Ralph Lauren, 1 New Bond St, Mayfair, London W1S 3LU, United Kingdom",             
             "Baxter, 2 Cavendish Square, Marylebone, London W1G 0PU, United Kingdom",             
             "Impact Assets, 6 Snow Hill, London EC1A 2AY, United Kingdom",             
             "Pharmacierge, 25 Harley St, Marylebone, London W1G 9QW, United Kingdom",
             "Ahli United Bank, 20 St Mary Axe, London EC3A 8AE, United Kingdom",
             "Attestor Limited, 20 Berkeley Square, Mayfair, London W1J 6EQ, United Kingdom",
             "Albemarle Independent College, 39-41 Norwood Rd, Herne Hill, London SE24 9AJ, United Kingdom",
            "London Stock Exchange, 10 Paternoster Square, London EC4M 7LS, UK",
            "Mercer, 1 Tower Pl, Tower Hill, London EC3R 5BU, UK",
            "Multiplex Construction Europe Ltd, 22 Hanover Square, Mayfair, London W1S 1JP, UK",
            "Oath (UK) Limited, 25-29 N Wall Quay, North Dock, Dublin 1, Ireland",
            "Pricewaterhouse Coopers, 1 Embankment Pl, London WC2N 6RH, UK",
            "Samsung Electronics (UK) Ltd, 1000 Hillswood Dr, Chertsey KT16 0PS, UK",
            "Societe Generale, 41 Tower Hill, London EC3N 4SG, UK",
            "Talk Talk Plc, Soapworks, Ordsall Ln, Salford M5 3TT, UK",
            "The Boston Consulting Group UK LLP, 20 Manchester Square, Marylebone, London W1U 3PZ, UK",
            "Travers Smith LLP, 10 Snow Hill, London EC1A 2AL, UK",
            "Aviva - Large Corporates - HCGLRG, St Helens 1 Undershaft, London EC3P 3DQ, UK",
            "Simplyhealth Partner Portal, Hambleden House, Water Ln, Wilmslow SK9 5BG, UK",
            "Accenture, 30 Fenchurch St, London EC3M 3BD, UK",
            "MediCash, Beaufort House, Brunswick Rd, Gloucester GL1 1JZ, UK",
            "Farfetch, The Bower, 207 Old St, London EC1V 9NR, UK",
            "Bank of America, 2 King Edward St, London EC1A 1HQ, UK",
            "PricewaterhouseCoopers Services Ltd, 7 More London Riverside, London SE1 2RT, UK",
            "Perkbox Limited, 22 Tudor St, Temple, London EC4Y 0AY, UK",
            "Immediate Media, Vineyard House, 44 Brook Green, Hammersmith, London W6 7BT, UK",
            "The Crown Estate, 1 St James's Market, St. James's, London SW1Y 4AH, UK",
            "Ares Management Limited, 2 Queen Caroline St, Hammersmith, London W6 9DX, UK",
            "Wagamama, 76 Wigmore St, Marylebone, London W1U 2SJ, UK",
            "Tastecard, 2nd floor, noco, 27-28 Eastcastle St, Fitzrovia, London W1W 8DH, UK",
            "Tiger Recruitment Ltd, 22 Grosvenor Square, Mayfair, London W1K 6JA, UK",
            "Avanade (UK) Limited, 15th Floor, 125 London Wall, London EC2Y 5AS, UK",
            "JP Morgan, 25 Bank St, Canary Wharf, London E14 5JP, UK",
            "COGS Employee Benefits - Cogs Salary Plus, 2nd Floor, 9 Devonshire Square, London EC2M 4YF, UK",
            "Lane Clark & Peacock LLP, 95 Wigmore St, Marylebone, London W1U 1DQ, UK",
            "PricewaterhouseCoopers Services Ltd, 7 More London Riverside, London SE1 2RT, UK",
            "Global Prime Partners, 10 Fitzmaurice Pl, Mayfair, London W1J 5JW, UK",
            "Attestor Capital, 20 Berkeley Square, Mayfair, London W1J 6EQ, UK",
            "Anaplan, 1 Berkeley St, Mayfair, London W1J 8DJ, UK",
            "Invesco, 30 Finsbury Square, London EC2A 1AG, UK",
            "Zeus Capital, 52 Brook Street, Mayfair, London W1K 5DS, UK",
            "Barratt Homes, Alderman's House, 34-37 Bow Lane, London EC4M 9DN, UK",
            "Adyen, 22 Hanover Square, Mayfair, London W1S 1JP, UK",
            "Engine MHP, 60 Great Portland St, Marylebone, London W1W 7RT, UK",
            "Bainbridge Partners LLP, 14 Hanover Square, Mayfair, London W1S 1JY, UK",
            "Essence Global, 4 Cavendish Square, Marylebone, London W1G 0PG, UK",
            "MFS UK, 5th Floor, 125 Old Broad St, London EC2N 1AR, UK",
            "NAO, 157-197 Buckingham Palace Rd, Victoria, London SW1W 9SP, UK",
            "RTL AdConect, 13-14 Dover St, Mayfair, London W1S 4LJ, UK",
            "iwoca, 3-4 Kirby St, Farringdon, London EC1N 8TS, UK",
            "Cromwell, 2 Mill St, Mayfair, London W1S 2AT, UK",
            "EVERCORE, 130 Jermyn St, St. James's, London SW1Y 4UR, UK",
            "H&M, 174-176 Oxford St, Soho, London W1D 1NX, UK",
            "GAP, 376-384 Oxford St, Marylebone, London W1C 1JY, UK",
            "Polen Capital, 12 Berkeley St, Mayfair, London W1J 8DT, UK",
            "Which Group, 27-28 Eastcastle St, Fitzrovia, London W1W 8DH, UK",
            "Prime Energy, 11 Berkeley St, Mayfair, London W1J 8DS, UK",
            "Ninetyone PLC, 10 Hanover Square, Mayfair, London W1S 1JG, UK",
            "TPG, 3rd Floor, 20 Grosvenor Pl, Belgravia, London SW1X 7HN, UK",
            "CBC group, 1-3 Strand, London WC2N 5JR, UK",
            "Blackstone, Devonshire House, 1 Mayfair Place, London W1J 8AJ, UK",
            "Titan asset management, 2 Mount St, Mayfair, London W1K 3HD, UK",
            "Wizer, 27-28 Eastcastle St, Fitzrovia, London W1W 8DH, UK",
            "Partners group UK, 2 Stanhope Gate, Mayfair, London W1K 1AF, UK",
            "7 Bridges LDP, 19 Berkeley St, Mayfair, London W1J 8ED"]

# %%
import pandas as pd
from opencage.geocoder import OpenCageGeocode
import time
import folium
from folium.plugins import HeatMap

# Replace this list with the actual company addresses in Mayfair
# Replace "your_api_key" with your actual API key
api_key = "0b1bedae6fc044e5a39146644c4b967d"
geocoder = OpenCageGeocode(api_key)

# Define function to get latitude and longitude for a given location
def get_lat_long(location):
    time.sleep(1)
    try:
        results = geocoder.geocode(location)
        lat = results[0]["geometry"]["lat"]
        lon = results[0]["geometry"]["lng"]
        return (lat, lon)
    except:
        return (None, None)

# Get latitude and longitude for each company
locations = {}
for company in companies:
    print(f"Processing {company}...")
    lat, lon = get_lat_long(company)
    locations[company] = {"latitude": lat, "longitude": lon}

print (locations)

# Create DataFrame of locations
locations_df = pd.DataFrame(locations).T
locations_df.to_csv("company_locations.csv")
print("Saved location data to CSV file")

# Create heatmap using Folium
london_coordinates = (51.5074, 0.1278)
heat_map = folium.Map(location=london_coordinates, zoom_start=15)

# Add heatmap layer to the map
heat_data = [[row["latitude"], row["longitude"]] for index, row in locations_df.iterrows() if row["latitude"] is not None and row["longitude"] is not None]
HeatMap(heat_data).add_to(heat_map)

# Save the heatmap to an HTML file
heat_map.save("heat_map.html")

# Display the heatmap
heat_map
# Out:
# Processing Fifth Fifth Season, 48 Tottenham Court Rd, Bloomsbury, London W1T 2EG, United Kingdom...
# Processing Time Family, 20-22 Wenlock Rd, Hoxton, London N1 7GU, United Kingdom...
# Processing Weight Watchers, 37-39 Oxford St, Soho, London W1D 2DU, United Kingdom...
# Processing Alpha, 20 Old Bailey, London EC4M 7AN, United Kingdom...
# Processing Remedy Analytics, 5 New St Square, London EC4A 3TW, United Kingdom...
# Processing Ralph Lauren, 1 New Bond St, Mayfair, London W1S 3LU, United Kingdom...
# Processing Baxter, 2 Cavendish Square, Marylebone, London W1G 0PU, United Kingdom...
# Processing Impact Assets, 6 Snow Hill, London EC1A 2AY, United Kingdom...
# Processing Pharmacierge, 25 Harley St, Marylebone, London W1G 9QW, United Kingdom...
# Processing Ahli United Bank, 20 St Mary Axe, London EC3A 8AE, United Kingdom...
# Processing Attestor Limited, 20 Berkeley Square, Mayfair, London W1J 6EQ, United Kingdom...
# ...
